# %%
import numpy as np
import pandas as pd
from __future__ import print_function

# %%
# !pip install xlrd
print("xlrd installed")
# Out:
# ...
# xlrd installed

# %%
df_can = pd.read_excel(
    'https://ibm.box.com/shared/static/lw190pt9zpy5bdlptyg2aw15awomz9pu.xlsx',
    sheet_name="Canada by Citizenship",  # updated parameter name
    skiprows=range(20),
    engine='openpyxl'  # required for .xlsx files from URLs
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_can = pd.read_excel(
#       2     'https://ibm.box.com/shared/static/lw190pt9zpy5bdlptyg2aw15awomz9pu.xlsx',
#       3     sheet_name="Canada by Citizenship",  # updated parameter name
#       4     skiprows=range(20),
#       5     engine='openpyxl'  # required for .xlsx files from URLs
#       6 )
#
# File ~/git/data-visuals/env/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# ...
